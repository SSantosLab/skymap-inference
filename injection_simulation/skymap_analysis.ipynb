# %%
import matplotlib.image as img
import matplotlib.pyplot as plt

# %%
! ligo-skymap-from-samples --maxpts 1000 data/simlogs/HL4/HL4-injection-uniform_posterior_samples.dat
# Out:
# 2022-07-28 13:34:50,883 INFO reading samples
# 2022-07-28 13:34:51,010 INFO taking random subsample of chain
# 2022-07-28 13:34:51,018 INFO clustering ...
# 100%|█████████████████████████████████████████| 200/200 [00:22<00:00,  9.01it/s]
# 2022-07-28 13:35:13,211 INFO clustering ...
# 100%|█████████████████████████████████████████| 200/200 [00:14<00:00, 13.74it/s]
# 2022-07-28 13:35:27,764 INFO pickling
# 2022-07-28 13:35:27,766 INFO making skymap
# adaptive refinement round 1 of 7 ...
# adaptive refinement round 2 of 7 ...
# adaptive refinement round 3 of 7 ...
# adaptive refinement round 4 of 7 ...
# adaptive refinement round 5 of 7 ...
# adaptive refinement round 6 of 7 ...
# adaptive refinement round 7 of 7 ...
# evaluating distance layers ...
# 100%|███████████████████████████████████| 16896/16896 [00:07<00:00, 2349.03it/s]

# %%
! ligo-skymap-plot skymap.fits -o skymap.png --annotate --contour 50 90

# %%
fig, ax = plt.subplots(dpi=200)
plt.axis('off')
plot = ax.imshow(img.imread('skymap.png'))

# %%
! ligo-skymap-from-samples --maxpts 1000 data/simlogs/HL3/HL3-injection-healpix_posterior_samples.dat
# Out:
# 2022-07-25 13:43:45,570 INFO reading samples
# 2022-07-25 13:43:45,870 INFO taking random subsample of chain
# 2022-07-25 13:43:45,881 INFO clustering ...
# 100%|█████████████████████████████████████████| 200/200 [00:32<00:00,  6.17it/s]
# 2022-07-25 13:44:18,316 INFO clustering ...
# 100%|█████████████████████████████████████████| 200/200 [00:15<00:00, 12.81it/s]
# 2022-07-25 13:44:33,923 INFO pickling
# 2022-07-25 13:44:33,925 INFO making skymap
# adaptive refinement round 1 of 7 ...
# adaptive refinement round 2 of 7 ...
# adaptive refinement round 3 of 7 ...
# adaptive refinement round 4 of 7 ...
# adaptive refinement round 5 of 7 ...
# adaptive refinement round 6 of 7 ...
# adaptive refinement round 7 of 7 ...
# evaluating distance layers ...
# 100%|███████████████████████████████████| 16896/16896 [00:05<00:00, 3314.87it/s]

# %%
! ligo-skymap-plot skymap.fits -o skymap.png --annotate --contour 50 90

# %%
fig, ax = plt.subplots(dpi=200)
plt.axis('off')
plot = ax.imshow(img.imread('skymap.png'))
